# %%
# !git clone https://github.com/2274802010922/Weather-Chatbot-with-Interactive-Map.git
# %cd Weather-Chatbot-with-Interactive-Map
# !pip install -r requirements.txt
# !python train_model.py
# Out:
# Cloning into 'Weather-Chatbot-with-Interactive-Map'...
# remote: Enumerating objects: 72, done.
# remote: Counting objects: 100% (72/72), done.
# remote: Compressing objects: 100% (68/68), done.
# remote: Total 72 (delta 28), reused 2 (delta 1), pack-reused 0 (from 0)
# Receiving objects: 100% (72/72), 31.45 KiB | 1.08 MiB/s, done.
# Resolving deltas: 100% (28/28), done.
# /content/Weather-Chatbot-with-Interactive-Map/Weather-Chatbot-with-Interactive-Map
# ...
# Building dataset...
# Loaded forecast data for Hanoi
# Loaded forecast data for Ho Chi Minh City
# Loaded forecast data for Da Nang
# Loaded forecast data for Can Tho
# Error loading data for Hai Phong: 404 Client Error: Not Found for url: https://api.openweathermap.org/data/2.5/forecast?q=Hai+Phong&appid=703d35b679aa8f01b02eff474186a6b0&units=metric&lang=vi
# Saved dataset to weather_dataset.csv
#
# Model comparison:
#                Model       MAE      RMSE        R2
# 0  Linear Regression  0.001320  0.001714  1.000000
# ...

# %%
# !python train_model.py
# Out:
# Building dataset...
# Loaded forecast data for Hanoi
# Loaded forecast data for Ho Chi Minh City
# Loaded forecast data for Da Nang
# Loaded forecast data for Can Tho
# Error loading data for Hai Phong: 404 Client Error: Not Found for url: https://api.openweathermap.org/data/2.5/forecast?q=Hai+Phong&appid=703d35b679aa8f01b02eff474186a6b0&units=metric&lang=vi
# Saved dataset to weather_dataset.csv
#
# Model comparison:
#                Model       MAE      RMSE        R2
# 0  Linear Regression  0.001320  0.001714  1.000000
# 2  Gradient Boosting  0.064692  0.089624  0.999465
# 1      Random Forest  0.077731  0.129263  0.998888
# Saved model comparison to model_comparison.csv
# Best model: Linear Regression
# Saved best model to weather_model.pkl

# %%
# !ls -lh
# Out:
# total 48K
# -rw-r--r-- 1 root root 6.2K Mar 18 11:58 app.py
# -rw-r--r-- 1 root root  246 Mar 18 11:59 model_comparison.csv
# -rw-r--r-- 1 root root 1.4K Mar 18 11:58 README.md
# -rw-r--r-- 1 root root   66 Mar 18 11:58 requirements.txt
# -rw-r--r-- 1 root root 4.2K Mar 18 11:58 train_model.py
# -rw-r--r-- 1 root root  11K Mar 18 11:59 weather_dataset.csv
# -rw-r--r-- 1 root root 1.6K Mar 18 11:58 weather_ml.py
# -rw-r--r-- 1 root root 1.1K Mar 18 11:59 weather_model.pkl

# %%
# !ls
# Out:
# app.py		      README.md		train_model.py	     weather_ml.py
# model_comparison.csv  requirements.txt	weather_dataset.csv  weather_model.pkl

# %%
from google.colab import files
files.download("weather_dataset.csv")
files.download("model_comparison.csv")
files.download("weather_model.pkl")

# %%
files.download("model_comparison.csv")

# %%
files.download("weather_model.pkl")

# %%
# !zip weather_ml_outputs.zip weather_dataset.csv model_comparison.csv weather_model.pkl
# Out:
#   adding: weather_dataset.csv (deflated 73%)
#   adding: model_comparison.csv (deflated 29%)
#   adding: weather_model.pkl (deflated 31%)

# %%
from google.colab import files
files.download("weather_ml_outputs.zip")

# %%
import kagglehub

# Download dataset
path = kagglehub.dataset_download("muthuj7/weather-dataset")

print("Path to dataset:", path)
# Out:
# Using Colab cache for faster access to the 'weather-dataset' dataset.
# Path to dataset: /kaggle/input/weather-dataset

# %%
import os

for file in os.listdir(path):
    print(file)
# Out:
# weatherHistory.csv

# %%
import shutil

shutil.copy(
    os.path.join(path, "weatherHistory.csv"),
    "/content/Weather-Chatbot-with-Interactive-Map/weatherHistory.csv"
)
# Out:
# '/content/Weather-Chatbot-with-Interactive-Map/weatherHistory.csv'

# %%
# !ls
# Out:
# app.py		      requirements.txt	   weather_ml_outputs.zip
# model_comparison.csv  train_model.py	   weather_ml.py
# README.md	      weather_dataset.csv  weather_model.pkl

# %%
# !find /content -name "weatherHistory.csv"
# Out:
# /content/Weather-Chatbot-with-Interactive-Map/weatherHistory.csv

# %%
from google.colab import files
files.download("/content/Weather-Chatbot-with-Interactive-Map/weatherHistory.csv")
